# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Walmart Salesdata.csv")

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
# Convert "Date" to datetime formate
df['Date'] =  pd.to_datetime(df['Date'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
df.head(10)
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
# 5      1 2010-03-12    1439541.59             0        57.79       2.667
# 6      1 2010-03-19    1472515.79             0        54.58       2.720
# 7      1 2010-03-26    1404429.92             0        51.45       2.732
# 8      1 2010-04-02    1594968.28             0        62.27       2.719
# 9      1 2010-04-09    1545418.53             0        65.86       2.770
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# 5  211.380643         8.106
# 6  211.215635         8.106
# 7  211.018042         8.106
# 8  210.820450         7.808
# 9  210.622857         7.808

# %%
df.tail()
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %% [markdown]
# # Visualize quantitative variables

# %%
walmart_data = df[['Weekly_Sales','Temperature', 'Fuel_Price', 'CPI', 'Unemployment']]
walmart_data.head()
# Out:
#    Weekly_Sales  Temperature  Fuel_Price         CPI  Unemployment
# 0    1643690.90        42.31       2.572  211.096358         8.106
# 1    1641957.44        38.51       2.548  211.242170         8.106
# 2    1611968.17        39.93       2.514  211.289143         8.106
# 3    1409727.59        46.63       2.561  211.319643         8.106
# 4    1554806.68        46.50       2.625  211.350143         8.106

# %%
walmart_data.hist(bins=10, grid= False, figsize=(10,10), color='skyblue', edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'Weekly_Sales'}>,
#         <Axes: title={'center': 'Temperature'}>],
#        [<Axes: title={'center': 'Fuel_Price'}>,
#         <Axes: title={'center': 'CPI'}>],
#        [<Axes: title={'center': 'Unemployment'}>, <Axes: >]], dtype=object)

# %% [markdown]
# # Correlation between Weekly Sales and other features

# %%
walmart_data = df[['Weekly_Sales','Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment']]
sns.heatmap(walmart_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# Conclusion : The is no relationship between Weekly Sales and other numerical features as the correlation between them is very near to zero

# %%
# set the figure size for the subplots
plt.figure(figsize=(10, 10))


# 1st subplot ('Temperature')
plt.subplot(2,2,1)
sns.boxplot(y = walmart_data['Temperature'])
plt.xlabel('Temperature')
plt.ylabel('Values')
plt.title('Boxplot of Temperature')

# 2nd subplot ('Fuel_Price')
plt.subplot(2,2,2)
sns.boxplot(y = walmart_data['Fuel_Price'])
plt.xlabel('Fuel_Price')
plt.ylabel('Values')
plt.title('Boxplot of Fuel_Price')

# 3rd subplot ('CPI')
plt.subplot(2,2,3)
sns.boxplot(y = walmart_data['CPI'])
plt.xlabel('CPI')
plt.ylabel('Values')
plt.title('Boxplot of CPI')

# 4th subplot ('Unemployment')
plt.subplot(2,2,4)
sns.boxplot(y = walmart_data['Unemployment'])
plt.xlabel('Unemployment')
plt.ylabel('Values')
plt.title('Boxplot of Unemployment')
# Out:
# Text(0.5, 1.0, 'Boxplot of Unemployment')

# %%
# Drop outliers
walmart_data = walmart_data[(walmart_data['Temperature']>10) & (walmart_data['Unemployment']>4.5) & (walmart_data['Unemployment']<10)]
walmart_data.head()
# Out:
#    Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0    1643690.90             0        42.31       2.572  211.096358
# 1    1641957.44             1        38.51       2.548  211.242170
# 2    1611968.17             0        39.93       2.514  211.289143
# 3    1409727.59             0        46.63       2.561  211.319643
# 4    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106

# %% [markdown]
# # Data Cleaning

# %%
# Check for null values
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# Check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
#  ## Q.1 Which store has maximum sales

# %%
gp = df.groupby('Store').agg({'Weekly_Sales':'sum'}).sort_values(by='Weekly_Sales',ascending=False)
gp.head(1)
# Out:
#        Weekly_Sales
# Store
# 20     3.013978e+08

# %%
gp.plot(kind='bar')

# Optional: Customize the plot
plt.title('Total Weekly Sales by Store')
plt.xlabel('Store')
plt.ylabel('Total Weekly Sales')

# Step 3: Show the plot
plt.show()

# %% [markdown]
# ## Q.2 Which store has maximum standard deviation i.e., the sales vary a lot. Also, find out the coefficient of mean to standard deviation

# %%
max_std = df.groupby('Store')['Weekly_Sales'].std().sort_values(ascending=False)
max_std.head(1)
# Out:
# Store
# 14    317569.949476
# Name: Weekly_Sales, dtype: float64

# %%
# Bar plot visualize the stores with their std, the max and min store's std
plt.figure(figsize=(5, 5))
max_std.plot(kind='bar')
# Out:
# <Axes: xlabel='Store'>

# %% [markdown]
# Histogram shows the frequencies of standard deviations for each store

# %%
max_std.plot(kind='hist', bins=15, edgecolor= 'black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Here Store 14 has the maximum standared deviation (its sales vary alot)

# %% [markdown]
# ## Q.3 Some holidays have a negative impact on sales. Find out holidays that have higher sales than the mean sales in the non-holiday season for all stores together.

# %%
# Holidays Events
Super_Bowl =['12-2-2010', '11-2-2011', '10-2-2012']
Labour_Day =  ['10-9-2010', '9-9-2011', '7-9-2012']
Thanksgiving =  ['26-11-2010', '25-11-2011', '23-11-2012']
Christmas = ['31-12-2010', '30-12-2011', '28-12-2012']

# %%
# Find the mean for all stores sales for each day
non_holidays_sales = df[df['Holiday_Flag'] == 0]['Weekly_Sales'].mean()
non_holidays_sales
# Out:
# 1041256.3802088555

# %%
# Find the mean for all stores sales for holidays 
# day_sales.loc[day_sales.Date.isin(Super_Bowl)]
# Convert holiday lists to datetime objects
Super_Bowl = pd.to_datetime(Super_Bowl, format='%d-%m-%Y')
Labour_Day = pd.to_datetime(Labour_Day, format='%d-%m-%Y')
Thanksgiving = pd.to_datetime(Thanksgiving, format='%d-%m-%Y')
Christmas = pd.to_datetime(Christmas, format='%d-%m-%Y')

# Filter data for each holiday and calculate mean of total store sales
super_bowl_sales = df[df['Date'].isin(Super_Bowl)]['Weekly_Sales'].mean()
labour_day_sales = df[df['Date'].isin(Labour_Day)]['Weekly_Sales'].mean()
thanksgiving_sales = df[df['Date'].isin(Thanksgiving)]['Weekly_Sales'].mean()
christmas_sales = df[df['Date'].isin(Christmas)]['Weekly_Sales'].mean()

print("super_bowl_sales: ", super_bowl_sales)
print("labour_day_sales: ", labour_day_sales)
print("thanksgiving_sales: ", thanksgiving_sales)
print("christmas_sales: ", christmas_sales)
print("non_holidays_sales: ", non_holidays_sales)
# Out:
# super_bowl_sales:  1079127.9877037038
# labour_day_sales:  1042427.293925926
# thanksgiving_sales:  1471273.427777778
# christmas_sales:  960833.1115555555
# non_holidays_sales:  1041256.3802088555

# %% [markdown]
# As noticed, Thanks giving, Super bowl, and Labour day have higher sales than the mean sales in the non-holiday season for all stores together.

# %% [markdown]
# ## Q.4 Provide a monthly and semester view of sales in units and give insights.¶

# %%
# Create new columns for months and years  
df['Month'] = pd.DatetimeIndex(df['Date']).month
df['Year'] = pd.DatetimeIndex(df['Date']).year
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Month  Year
# 0  211.096358         8.106      2  2010
# 1  211.242170         8.106      2  2010
# 2  211.289143         8.106      2  2010
# 3  211.319643         8.106      2  2010
# 4  211.350143         8.106      3  2010

# %%
plt.figure(figsize=(10,6))
plot = sns.barplot(x=df[df.Year==2010]['Month'], y=df[df.Year==2010]['Weekly_Sales'])
plt.title('Monthly sales review in 2010')
plot.bar_label(plot.containers[0], padding= 25, fontsize=7)
# Out:
# [Text(0, 25, '1.05741e+06'),
#  Text(0, 25, '1.01067e+06'),
#  Text(0, 25, '1.0285e+06'),
#  Text(0, 25, '1.03728e+06'),
#  Text(0, 25, '1.06803e+06'),
#  Text(0, 25, '1.03369e+06'),
#  Text(0, 25, '1.04245e+06'),
#  Text(0, 25, '984822'),
#  Text(0, 25, '965164'),
#  Text(0, 25, '1.12696e+06'),
#  Text(0, 25, '1.28338e+06')]

# %% [markdown]
# Conclusion : As noticed, December was the highest month in sales in 2010 and Octuber was the least one

# %%
plt.figure(figsize=(10,6))
plot = sns.barplot(x=df[df.Year==2011]['Month'], y=df[df.Year==2011]['Weekly_Sales'])
plt.title('Monthly sales review in 2011')
plot.bar_label(plot.containers[0], padding= 25, fontsize=6)
# Out:
# [Text(0, 25, '909466'),
#  Text(0, 25, '1.03517e+06'),
#  Text(0, 25, '996425'),
#  Text(0, 25, '1.00678e+06'),
#  Text(0, 25, '1.00916e+06'),
#  Text(0, 25, '1.0543e+06'),
#  Text(0, 25, '1.02183e+06'),
#  Text(0, 25, '1.04777e+06'),
#  Text(0, 25, '981546'),
#  Text(0, 25, '1.01812e+06'),
#  Text(0, 25, '1.16757e+06'),
#  Text(0, 25, '1.28035e+06')]

# %% [markdown]
# Conclusion : As noticed, December was the highest month in sales in 2011 and January was the least one

# %% [markdown]
# Dataset provides data of 10 months only in 2012

# %%
plt.figure(figsize=(10,6))
plot = sns.barplot(x=df[df.Year==2012]['Month'], y=df[df.Year==2012]['Weekly_Sales'])
plt.title('Monthly sales review in 2012')
plot.bar_label(plot.containers[0], padding= 25, fontsize=8)
# Out:
# [Text(0, 25, '938303'),
#  Text(0, 25, '1.06702e+06'),
#  Text(0, 25, '1.02893e+06'),
#  Text(0, 25, '1.04956e+06'),
#  Text(0, 25, '1.0487e+06'),
#  Text(0, 25, '1.06938e+06'),
#  Text(0, 25, '1.04172e+06'),
#  Text(0, 25, '1.05267e+06'),
#  Text(0, 25, '1.00359e+06'),
#  Text(0, 25, '1.02423e+06')]

# %% [markdown]
# In the 10 months of 2012, Jun was the highest month in sales and January was the least one

# %% [markdown]
# # Semester Sales Review

# %%
# Define function to determine the semester based on month
def get_semester(month):
    if month in range(1, 7):
        return '1st Semester'
    else:
        return '2nd Semester'

# Apply the function to create 'Semester' column
df['Semester'] = df['Month'].apply(get_semester)
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Month  Year      Semester
# 0  211.096358         8.106      2  2010  1st Semester
# 1  211.242170         8.106      2  2010  1st Semester
# 2  211.289143         8.106      2  2010  1st Semester
# 3  211.319643         8.106      2  2010  1st Semester
# 4  211.350143         8.106      3  2010  1st Semester

# %%
semester_sales = df.groupby('Semester')['Weekly_Sales'].sum()
semester_sales
# Out:
# Semester
# 1st Semester    3.320727e+09
# 2nd Semester    3.416492e+09
# Name: Weekly_Sales, dtype: float64

# %%
sns.barplot(y=semester_sales, x=semester_sales.index)
# Out:
# <Axes: xlabel='Semester', ylabel='Weekly_Sales'>

# %% [markdown]
# The sales in 2nd semester is little greater than the sales in the 1st one.

# %% [markdown]
# # Yearly review of Sales

# %%
yearly_sales = pd.DataFrame(df.groupby('Year')['Weekly_Sales'].sum())

plt.figure(figsize=(10,6))
plot = sns.barplot(x = yearly_sales.index, y = yearly_sales['Weekly_Sales'], width=0.5)
plot.bar_label(plot.containers[0], padding=3, fontsize=8)
# Out:
# [Text(0, 3, '2.28889e+09'),
#  Text(0, 3, '2.4482e+09'),
#  Text(0, 3, '2.00013e+09')]

# %% [markdown]
# As noticed, 2011 was the highest year in sales and 2012 was the least one

# %% [markdown]
# # 5. Plot the relations between weekly sales vs. other numeric features and give insights.

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
sns.lineplot(x=walmart_data['Temperature'], y=walmart_data['Weekly_Sales'], errorbar=None)
plt.title('Weekly_Sales vs Temperature')
plt.subplot(2,1,2)
sns.scatterplot(x=walmart_data['Temperature'], y=walmart_data['Weekly_Sales'])
plt.show()

# %%
# plt.figure(figsize=(10,6))
# sns.lineplot(x=walmart_data['Fuel_Price'], y=walmart_data['Weekly_Sales'], errorbar=None)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
sns.lineplot(x=walmart_data['Fuel_Price'], y=walmart_data['Weekly_Sales'], errorbar=None)
plt.title('Weekly_Sales vs Fuel_Price')
plt.subplot(2,1,2)
sns.scatterplot(x=walmart_data['Fuel_Price'], y=walmart_data['Weekly_Sales'])
plt.show()

# %%
# plt.figure(figsize=(10,6))
# sns.lineplot(x=walmart_data['CPI'], y=walmart_data['Weekly_Sales'], errorbar=None)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
sns.lineplot(x=walmart_data['CPI'], y=walmart_data['Weekly_Sales'], errorbar=None)
plt.title('Weekly_Sales vs CPI')
plt.subplot(2,1,2)
sns.scatterplot(x=walmart_data['CPI'], y=walmart_data['Weekly_Sales'])
plt.show()

# %%
sns.barplot(x=df['Holiday_Flag'], y=df['Weekly_Sales'])
# Out:
# <Axes: xlabel='Holiday_Flag', ylabel='Weekly_Sales'>

# %% [markdown]
# Conclusion : The sales in Holiday weeks is little greater than the sales in the non-Holiday weeks
